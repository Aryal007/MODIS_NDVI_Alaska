# %%
from pathlib import Path
import glob, os
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import pdb

# %%
DATA_DIR = Path("/datadrive/MODIS_NDVI_Alaska/modis/tiffs_numpy/")
SHAPEFILE_DIR = Path("/datadrive/MODIS_NDVI_Alaska/modis/shps/ROI_small")
OUT_DIR = Path("/datadrive/MODIS_NDVI_Alaska/modis/final_numpy/")

ANWR_DIR = DATA_DIR / "anwr"
IVOTUK_NORTH_DIR = DATA_DIR / "ivotuk_north"
IVOTUK_SOUTH_DIR = DATA_DIR / "ivotuk_south"
PRUDHOEBAY_DIR = DATA_DIR / "prudhoebay"

# %%
#dirs = ["anwr", "ivotuk_north", "ivotuk_south", "prudhoebay"]
year = "2000"
for region in dirs:
    _dir = DATA_DIR / region
    files = glob.glob(str(_dir / "*"))
    for fname in files:
        cname = os.path.basename(fname).split(".")[0]
        print(f"Woring on file {cname}")
        new_year = cname.split("_")[0]
        if new_year != year:
            arr = np.max(yearly_arr,axis=0)
            del(yearly_arr)
            try:
                df[year] = arr
            except:
                df = pd.DataFrame({
                                "location": np.arange(len(arr)),
                                 year: arr})
            year = new_year
        arr = np.float32(np.load(fname))
        arr = (arr + 2000) / 12000
        arr[arr == 0] = np.nan
        arr = arr.flatten()
        try:
            yearly_arr = np.vstack((yearly_arr, arr))
        except:
            yearly_arr = arr
    arr = np.max(yearly_arr,axis=0)
    df[year] = arr
    
    dropped_df = df.dropna(axis=0, how='any', inplace=False)
    dropped_df = dropped_df.drop(['location', '2000','2021'], axis=1)
    dropped_df.reset_index(drop=True, inplace=True)
    
    n_years = 20
    plot_arr = np.zeros((len(dropped_df)*n_years, 2))
    for (index, rows) in dropped_df.iterrows():
        ndvi = np.asarray(rows)
        slope_ndvi = np.gradient(ndvi)
        plot_arr[index*n_years:index*n_years+n_years, 0] = ndvi
        plot_arr[index*n_years:index*n_years+n_years, 1] = slope_ndvi
        
    savename = OUT_DIR / region
    np.save(savename, plot_arr)
    del(arr)
    del(yearly_arr)
    del(df)
    del(dropped_df)
# Out:
# Woring on file 2000_02_18
# Woring on file 2000_03_05
# Woring on file 2000_03_21
# Woring on file 2000_04_06
# Woring on file 2000_04_22
# Woring on file 2000_05_08
# Woring on file 2000_05_24
# Woring on file 2000_06_09
# Woring on file 2000_06_25
# Woring on file 2000_07_11
# Woring on file 2000_07_27
# Woring on file 2000_08_12
# Woring on file 2000_08_28
# Woring on file 2000_09_13
# Woring on file 2000_09_29
# Woring on file 2000_10_15
# Woring on file 2000_10_31
# Woring on file 2000_11_16
# Woring on file 2000_12_02
# Woring on file 2000_12_18
# Woring on file 2001_01_01
# Woring on file 2001_01_17
# Woring on file 2001_02_02
# Woring on file 2001_02_18
# Woring on file 2001_03_06
# Woring on file 2001_03_22
# Woring on file 2001_04_07
# Woring on file 2001_04_23
# Woring on file 2001_05_09
# Woring on file 2001_05_25
# Woring on file 2001_06_10
# Woring on file 2001_06_26
# Woring on file 2001_07_12
# Woring on file 2001_07_28
# Woring on file 2001_08_13
# Woring on file 2001_08_29
# Woring on file 2001_09_14
# Woring on file 2001_09_30
# Woring on file 2001_10_16
# Woring on file 2001_11_01
# Woring on file 2001_11_17
# Woring on file 2001_12_03
# Woring on file 2001_12_19
# Woring on file 2002_01_01
# Woring on file 2002_01_17
# Woring on file 2002_02_02
# Woring on file 2002_02_18
# Woring on file 2002_03_06
# Woring on file 2002_03_22
# Woring on file 2002_04_07
# Woring on file 2002_04_23
# Woring on file 2002_05_09
# Woring on file 2002_05_25
# Woring on file 2002_06_10
# Woring on file 2002_06_26
# Woring on file 2002_07_12
# Woring on file 2002_07_28
# Woring on file 2002_08_13
# Woring on file 2002_08_29
# Woring on file 2002_09_14
# Woring on file 2002_09_30
# Woring on file 2002_10_16
# Woring on file 2002_11_01
# Woring on file 2002_11_17
# Woring on file 2002_12_03
# Woring on file 2002_12_19
# Woring on file 2003_01_01
# Woring on file 2003_01_17
# Woring on file 2003_02_02
# Woring on file 2003_02_18
# Woring on file 2003_03_06
# Woring on file 2003_03_22
# Woring on file 2003_04_07
# Woring on file 2003_04_23
# Woring on file 2003_05_09
# Woring on file 2003_05_25
# Woring on file 2003_06_10
# Woring on file 2003_06_26
# Woring on file 2003_07_12
# Woring on file 2003_07_28
# Woring on file 2003_08_13
# Woring on file 2003_08_29
# Woring on file 2003_09_14
# Woring on file 2003_09_30
# Woring on file 2003_10_16
# Woring on file 2003_11_01
# Woring on file 2003_11_17
# Woring on file 2003_12_03
# Woring on file 2003_12_19
# Woring on file 2004_01_01
# Woring on file 2004_01_17
# Woring on file 2004_02_02
# Woring on file 2004_02_18
# Woring on file 2004_03_05
# Woring on file 2004_03_21
# Woring on file 2004_04_06
# Woring on file 2004_04_22
# Woring on file 2004_05_08
# Woring on file 2004_05_24
# Woring on file 2004_06_09
# Woring on file 2004_06_25
# Woring on file 2004_07_11
# Woring on file 2004_07_27
# Woring on file 2004_08_12
# Woring on file 2004_08_28
# Woring on file 2004_09_13
# Woring on file 2004_09_29
# Woring on file 2004_10_15
# Woring on file 2004_10_31
# Woring on file 2004_11_16
# Woring on file 2004_12_02
# Woring on file 2004_12_18
# Woring on file 2005_01_01
# Woring on file 2005_01_17
# Woring on file 2005_02_02
# Woring on file 2005_02_18
# Woring on file 2005_03_06
# Woring on file 2005_03_22
# Woring on file 2005_04_07
# Woring on file 2005_04_23
# Woring on file 2005_05_09
# Woring on file 2005_05_25
# Woring on file 2005_06_10
# Woring on file 2005_06_26
# Woring on file 2005_07_12
# Woring on file 2005_07_28
# Woring on file 2005_08_13
# Woring on file 2005_08_29
# Woring on file 2005_09_14
# Woring on file 2005_09_30
# Woring on file 2005_10_16
# Woring on file 2005_11_01
# Woring on file 2005_11_17
# Woring on file 2005_12_03
# Woring on file 2005_12_19
# Woring on file 2006_01_01
# Woring on file 2006_01_17
# Woring on file 2006_02_02
# Woring on file 2006_02_18
# Woring on file 2006_03_06
# Woring on file 2006_03_22
# Woring on file 2006_04_07
# Woring on file 2006_04_23
# Woring on file 2006_05_09
# Woring on file 2006_05_25
# Woring on file 2006_06_10
# Woring on file 2006_06_26
# Woring on file 2006_07_12
# Woring on file 2006_07_28
# Woring on file 2006_08_13
# Woring on file 2006_08_29
# Woring on file 2006_09_14
# Woring on file 2006_09_30
# Woring on file 2006_10_16
# Woring on file 2006_11_01
# Woring on file 2006_11_17
# Woring on file 2006_12_03
# Woring on file 2006_12_19
# Woring on file 2007_01_01
# Woring on file 2007_01_17
# Woring on file 2007_02_02
# Woring on file 2007_02_18
# Woring on file 2007_03_06
# Woring on file 2007_03_22
# Woring on file 2007_04_07
# Woring on file 2007_04_23
# Woring on file 2007_05_09
# Woring on file 2007_05_25
# Woring on file 2007_06_10
# Woring on file 2007_06_26
# Woring on file 2007_07_12
# Woring on file 2007_07_28
# Woring on file 2007_08_13
# Woring on file 2007_08_29
# Woring on file 2007_09_14
# Woring on file 2007_09_30
# Woring on file 2007_10_16
# Woring on file 2007_11_01
# Woring on file 2007_11_17
# Woring on file 2007_12_03
# Woring on file 2007_12_19
# Woring on file 2008_01_01
# Woring on file 2008_01_17
# Woring on file 2008_02_02
# Woring on file 2008_02_18
# Woring on file 2008_03_05
# Woring on file 2008_03_21
# Woring on file 2008_04_06
# Woring on file 2008_04_22
# Woring on file 2008_05_08
# Woring on file 2008_05_24
# Woring on file 2008_06_09
# Woring on file 2008_06_25
# Woring on file 2008_07_11
# Woring on file 2008_07_27
# Woring on file 2008_08_12
# Woring on file 2008_08_28
# Woring on file 2008_09_13
# Woring on file 2008_09_29
# Woring on file 2008_10_15
# Woring on file 2008_10_31
# Woring on file 2008_11_16
# Woring on file 2008_12_02
# Woring on file 2008_12_18
# Woring on file 2009_01_01
# Woring on file 2009_01_17
# Woring on file 2009_02_02
# Woring on file 2009_02_18
# Woring on file 2009_03_06
# Woring on file 2009_03_22
# Woring on file 2009_04_07
# Woring on file 2009_04_23
# Woring on file 2009_05_09
# Woring on file 2009_05_25
# Woring on file 2009_06_10
# Woring on file 2009_06_26
# Woring on file 2009_07_12
# Woring on file 2009_07_28
# Woring on file 2009_08_13
# Woring on file 2009_08_29
# Woring on file 2009_09_14
# Woring on file 2009_09_30
# Woring on file 2009_10_16
# Woring on file 2009_11_01
# Woring on file 2009_11_17
# Woring on file 2009_12_03
# Woring on file 2009_12_19
# Woring on file 2010_01_01
# Woring on file 2010_01_17
# Woring on file 2010_02_02
# Woring on file 2010_02_18
# Woring on file 2010_03_06
# Woring on file 2010_03_22
# Woring on file 2010_04_07
# Woring on file 2010_04_23
# Woring on file 2010_05_09
# Woring on file 2010_05_25
# Woring on file 2010_06_10
# Woring on file 2010_06_26
# Woring on file 2010_07_12
# Woring on file 2010_07_28
# Woring on file 2010_08_13
# Woring on file 2010_08_29
# Woring on file 2010_09_14
# Woring on file 2010_09_30
# Woring on file 2010_10_16
# Woring on file 2010_11_01
# Woring on file 2010_11_17
# Woring on file 2010_12_03
# Woring on file 2010_12_19
# Woring on file 2011_01_01
# Woring on file 2011_01_17
# Woring on file 2011_02_02
# Woring on file 2011_02_18
# Woring on file 2011_03_06
# Woring on file 2011_03_22
# Woring on file 2011_04_07
# Woring on file 2011_04_23
# Woring on file 2011_05_09
# Woring on file 2011_05_25
# Woring on file 2011_06_10
# Woring on file 2011_06_26
# Woring on file 2011_07_12
# Woring on file 2011_07_28
# Woring on file 2011_08_13
# Woring on file 2011_08_29
# Woring on file 2011_09_14
# Woring on file 2011_09_30
# Woring on file 2011_10_16
# Woring on file 2011_11_01
# Woring on file 2011_11_17
# Woring on file 2011_12_03
# Woring on file 2011_12_19
# Woring on file 2012_01_01
# Woring on file 2012_01_17
# Woring on file 2012_02_02
# Woring on file 2012_02_18
# Woring on file 2012_03_05
# Woring on file 2012_03_21
# Woring on file 2012_04_06
# Woring on file 2012_04_22
# Woring on file 2012_05_08
# Woring on file 2012_05_24
# Woring on file 2012_06_09
# Woring on file 2012_06_25
# Woring on file 2012_07_11
# Woring on file 2012_07_27
# Woring on file 2012_08_12
# Woring on file 2012_08_28
# Woring on file 2012_09_13
# Woring on file 2012_09_29
# Woring on file 2012_10_15
# Woring on file 2012_10_31
# Woring on file 2012_11_16
# Woring on file 2012_12_02
# Woring on file 2012_12_18
# Woring on file 2013_01_01
# Woring on file 2013_01_17
# Woring on file 2013_02_02
# Woring on file 2013_02_18
# Woring on file 2013_03_06
# Woring on file 2013_03_22
# Woring on file 2013_04_07
# Woring on file 2013_04_23
# Woring on file 2013_05_09
# Woring on file 2013_05_25
# Woring on file 2013_06_10
# Woring on file 2013_06_26
# Woring on file 2013_07_12
# Woring on file 2013_07_28
# Woring on file 2013_08_13
# Woring on file 2013_08_29
# Woring on file 2013_09_14
# Woring on file 2013_09_30
# Woring on file 2013_10_16
# Woring on file 2013_11_01
# Woring on file 2013_11_17
# Woring on file 2013_12_03
# Woring on file 2013_12_19
# Woring on file 2014_01_01
# Woring on file 2014_01_17
# Woring on file 2014_02_02
# Woring on file 2014_02_18
# Woring on file 2014_03_06
# Woring on file 2014_03_22
# Woring on file 2014_04_07
# Woring on file 2014_04_23
# Woring on file 2014_05_09
# Woring on file 2014_05_25
# Woring on file 2014_06_10
# Woring on file 2014_06_26
# Woring on file 2014_07_12
# Woring on file 2014_07_28
# Woring on file 2014_08_13
# Woring on file 2014_08_29
# Woring on file 2014_09_14
# Woring on file 2014_09_30
# Woring on file 2014_10_16
# Woring on file 2014_11_01
# Woring on file 2014_11_17
# Woring on file 2014_12_03
# Woring on file 2014_12_19
# Woring on file 2015_01_01
# Woring on file 2015_01_17
# Woring on file 2015_02_02
# Woring on file 2015_02_18
# Woring on file 2015_03_06
# Woring on file 2015_03_22
# Woring on file 2015_04_07
# Woring on file 2015_04_23
# Woring on file 2015_05_09
# Woring on file 2015_05_25
# Woring on file 2015_06_10
# Woring on file 2015_06_26
# Woring on file 2015_07_12
# Woring on file 2015_07_28
# Woring on file 2015_08_13
# Woring on file 2015_08_29
# Woring on file 2015_09_14
# Woring on file 2015_09_30
# Woring on file 2015_10_16
# Woring on file 2015_11_01
# Woring on file 2015_11_17
# Woring on file 2015_12_03
# Woring on file 2015_12_19
# Woring on file 2016_01_01
# Woring on file 2016_01_17
# Woring on file 2016_02_02
# Woring on file 2016_02_18
# Woring on file 2016_03_05
# Woring on file 2016_03_21
# Woring on file 2016_04_06
# Woring on file 2016_04_22
# Woring on file 2016_05_08
# Woring on file 2016_05_24
# Woring on file 2016_06_09
# Woring on file 2016_06_25
# Woring on file 2016_07_11
# Woring on file 2016_07_27
# Woring on file 2016_08_12
# Woring on file 2016_08_28
# Woring on file 2016_09_13
# Woring on file 2016_09_29
# Woring on file 2016_10_15
# Woring on file 2016_10_31
# Woring on file 2016_11_16
# Woring on file 2016_12_02
# Woring on file 2016_12_18
# Woring on file 2017_01_01
# Woring on file 2017_01_17
# Woring on file 2017_02_02
# Woring on file 2017_02_18
# Woring on file 2017_03_06
# Woring on file 2017_03_22
# Woring on file 2017_04_07
# Woring on file 2017_04_23
# Woring on file 2017_05_09
# Woring on file 2017_05_25
# Woring on file 2017_06_10
# Woring on file 2017_06_26
# Woring on file 2017_07_12
# Woring on file 2017_07_28
# Woring on file 2017_08_13
# Woring on file 2017_08_29
# Woring on file 2017_09_14
# Woring on file 2017_09_30
# Woring on file 2017_10_16
# Woring on file 2017_11_01
# Woring on file 2017_11_17
# Woring on file 2017_12_03
# Woring on file 2017_12_19
# Woring on file 2018_01_01
# Woring on file 2018_01_17
# Woring on file 2018_02_02
# Woring on file 2018_02_18
# Woring on file 2018_03_06
# Woring on file 2018_03_22
# Woring on file 2018_04_07
# Woring on file 2018_04_23
# Woring on file 2018_05_09
# Woring on file 2018_05_25
# Woring on file 2018_06_10
# Woring on file 2018_06_26
# Woring on file 2018_07_12
# Woring on file 2018_07_28
# Woring on file 2018_08_13
# Woring on file 2018_08_29
# Woring on file 2018_09_14
# Woring on file 2018_09_30
# Woring on file 2018_10_16
# Woring on file 2018_11_01
# Woring on file 2018_11_17
# Woring on file 2018_12_03
# Woring on file 2018_12_19
# Woring on file 2019_01_01
# Woring on file 2019_01_17
# Woring on file 2019_02_02
# Woring on file 2019_02_18
# Woring on file 2019_03_06
# Woring on file 2019_03_22
# Woring on file 2019_04_07
# Woring on file 2019_04_23
# Woring on file 2019_05_09
# Woring on file 2019_05_25
# Woring on file 2019_06_10
# Woring on file 2019_06_26
# Woring on file 2019_07_12
# Woring on file 2019_07_28
# Woring on file 2019_08_13
# Woring on file 2019_08_29
# Woring on file 2019_09_14
# Woring on file 2019_09_30
# Woring on file 2019_10_16
# Woring on file 2019_11_01
# Woring on file 2019_11_17
# Woring on file 2019_12_03
# Woring on file 2019_12_19
# Woring on file 2020_01_01
# Woring on file 2020_01_17
# Woring on file 2020_02_02
# Woring on file 2020_02_18
# Woring on file 2020_03_05
# Woring on file 2020_03_21
# Woring on file 2020_04_06
# Woring on file 2020_04_22
# Woring on file 2020_05_08
# Woring on file 2020_05_24
# Woring on file 2020_06_09
# Woring on file 2020_06_25
# Woring on file 2020_07_11
# Woring on file 2020_07_27
# Woring on file 2020_08_12
# Woring on file 2020_08_28
# Woring on file 2020_09_13
# Woring on file 2020_09_29
# Woring on file 2020_10_15
# Woring on file 2020_10_31
# Woring on file 2020_11_16
# Woring on file 2020_12_02
# Woring on file 2020_12_18
# Woring on file 2021_01_01
# Woring on file 2021_01_17
# Woring on file 2021_02_02
# Woring on file 2021_02_18
# Woring on file 2021_03_06
# Woring on file 2021_03_22
# Woring on file 2021_04_07
# Woring on file 2021_04_23
# Woring on file 2021_05_09
# Woring on file 2021_05_25
# Woring on file 2021_06_10
# Woring on file 2021_06_26
# Woring on file 2021_07_12
# Woring on file 2021_07_28

# %%
df.columns
# Out:
# Index(['location', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    location  2000  2001  2002  2003  2004  2005  2006  2007  2008  ...  2012  \
# 0         0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1         1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2         2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3         3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4         4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#    2013  2014  2015  2016  2017  2018  2019  2020  2021
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 23 columns]

# %%
dropped_df = df.dropna(axis=0, how='any', inplace=False)
dropped_df = dropped_df.drop(['location', '2000','2021'], axis=1)

# %%
dropped_df.reset_index(drop=True, inplace=True)
dropped_df.head()
# Out:
#        2001      2002     2003      2004      2005   2006      2007    2008  \
# 0  0.599583  0.598833  0.59425  0.600917  0.619583  0.585  0.597083  0.6045
# 1  0.599583  0.598833  0.59425  0.600917  0.619583  0.585  0.597083  0.6045
# 2  0.599583  0.598833  0.59425  0.600917  0.619583  0.585  0.597083  0.6045
# 3  0.599583  0.598833  0.59425  0.600917  0.619583  0.585  0.597083  0.6045
# 4  0.599583  0.598833  0.59425  0.600917  0.619583  0.585  0.597083  0.6045
#
#      2009      2010      2011      2012      2013    2014      2015      2016  \
# 0  0.5775  0.596833  0.620333  0.603417  0.622167  0.6435  0.651583  0.604833
# 1  0.5775  0.596833  0.620333  0.603417  0.622167  0.6435  0.651583  0.604833
# 2  0.5775  0.596833  0.620333  0.603417  0.622167  0.6435  0.651583  0.604833
# 3  0.5775  0.596833  0.620333  0.603417  0.622167  0.6435  0.651583  0.604833
# 4  0.5775  0.596833  0.620333  0.603417  0.622167  0.6435  0.651583  0.604833
#
#        2017   2018     2019      2020
# 0  0.646083  0.586  0.68575  0.681917
# 1  0.646083  0.586  0.68575  0.681917
# 2  0.646083  0.586  0.68575  0.681917
# 3  0.646083  0.586  0.68575  0.681917
# 4  0.646083  0.586  0.68575  0.681917

# %%
len(dropped_df)
