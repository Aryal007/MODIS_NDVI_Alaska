# %%
from pathlib import Path
import glob
import geopandas as gpd
from utils import *

# %% [markdown]
# ### Location where data is stored

# %%
DATA_DIR = Path("/datadrive/MODIS_NDVI_Alaska/modis/tiffs/")
SHAPEFILE_DIR = Path("/datadrive/MODIS_NDVI_Alaska/modis/shps/ROI_small")

ANWR_DIR = DATA_DIR / "anwr"
IVOTUK_NORTH_DIR = DATA_DIR / "ivotuk_north"
IVOTUK_SOUTH_DIR = DATA_DIR / "ivotuk_south"
PRUDHOEBAY_DIR = DATA_DIR / "prudhoebay"
ANWR_SHAPEFILE_DIR = SHAPEFILE_DIR / "ANWR_small.shp"
IVOTUK_NORTH_SHAPEFILE_DIR = SHAPEFILE_DIR / "Ivotuk_north_small.shp"
IVOTUK_SOUTH_SHAPEFILE_DIR = SHAPEFILE_DIR / "Ivotuk_south_small.shp"
PRUDHOEBAY_SHAPEFILE_DIR = SHAPEFILE_DIR / "PrudhoeBay_small.shp"

# %% [markdown]
# ### Read all files, sort, and make_dictionary

# %%
anwr_files = glob.glob(str(ANWR_DIR / "*"))
ivotuk_north_files = glob.glob(str(IVOTUK_NORTH_DIR / "*"))
ivotuk_south_files = glob.glob(str(IVOTUK_SOUTH_DIR / "*"))
prudhoebay_files = glob.glob(str(PRUDHOEBAY_DIR / "*"))
anwr_files.sort()
prudhoebay_files.sort()
ivotuk_north_files.sort()
ivotuk_south_files.sort()
files = {"anwr": anwr_files,
        "ivotuk_north": ivotuk_north_files,
        "ivotuk_south": ivotuk_south_files,
        "prudhoebay": prudhoebay_files}
anwr_label_file = gpd.read_file(ANWR_SHAPEFILE_DIR)
ivotuk_north_label_file = gpd.read_file(IVOTUK_NORTH_SHAPEFILE_DIR)
ivotuk_south_label_file = gpd.read_file(IVOTUK_SOUTH_SHAPEFILE_DIR)
prudhoebay_label_file = gpd.read_file(PRUDHOEBAY_SHAPEFILE_DIR)
labels = {"anwr": anwr_label_file,
        "ivotuk_north": ivotuk_north_label_file,
        "ivotuk_south": ivotuk_south_label_file,
        "prudhoebay": prudhoebay_label_file}

# %% [markdown]
# ### Print file Statistics

# %%
print_files_stats(files)
# Out:
# ***Printing stats for anwr***
#
# Total number of available files: 494
# First file: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_02_18.tif
# Last file: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2021_07_28.tif
#
# ***Printing stats for ivotuk_north***
#
# Total number of available files: 494
# First file: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/ivotuk_north/2000_02_18.tif
# Last file: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/ivotuk_north/2021_07_28.tif
#
# ***Printing stats for ivotuk_south***
#
# Total number of available files: 494
# First file: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/ivotuk_south/2000_02_18.tif
# Last file: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/ivotuk_south/2021_07_28.tif
#
# ***Printing stats for prudhoebay***
#
# Total number of available files: 494
# First file: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/prudhoebay/2000_02_18.tif
# Last file: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/prudhoebay/2021_07_28.tif

# %% [markdown]
# ### Number of files per year/month

# %%
bar_files_by(files, "year")

# %%
bar_files_by(files, "month")

# %%
masks = {"anwr": get_mask(rasterio.open(files['anwr'][0]), labels['anwr']),
        "ivotuk_north": get_mask(rasterio.open(files['ivotuk_north'][0]), labels['ivotuk_north']),
        "ivotuk_south": get_mask(rasterio.open(files['ivotuk_south'][0]), labels['ivotuk_south']),
        "prudhoebay": get_mask(rasterio.open(files['prudhoebay'][0]), labels['prudhoebay'])}
# Out:
# /home/aryal007/anaconda3/envs/py36/lib/python3.6/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# ### ANWR NDVI Sample

# %%
for i in range(50,53):
    vis_tiff(files['anwr'][i], masks['anwr'], vmax=1, vflip=True)

# %% [markdown]
# ### ivotuk NDVI sample

# %%
for i in range(28,31):
    vis_tiff(files['ivotuk_north'][i], masks['ivotuk_north'], vmax=1, vflip=True)
    vis_tiff(files['ivotuk_south'][i], masks['ivotuk_south'], vmax=1, vflip=True)

# %% [markdown]
# ### prudhoebay NDVI samples

# %%
for i in range(50,53):
    vis_tiff(files['prudhoebay'][i], masks['prudhoebay'], vmax=1, vflip=True)

# %%
for key, value in masks.items():
    OUT_DIR = Path(f"/datadrive/MODIS_NDVI_Alaska/modis/tiffs_numpy/{key}")
    if not os.path.exists(OUT_DIR):
        os.makedirs(OUT_DIR, exist_ok=True)
    for i, f in enumerate(files[key]):
        print(f"{key} image {i+1} out of {len(files[key])}")
        save_tiff_numpy(OUT_DIR, f, value, vflip=True)
# Out:
# anwr image 1 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_02_18.tif
# anwr image 2 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_03_05.tif
# anwr image 3 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_03_21.tif
# anwr image 4 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_04_06.tif
# anwr image 5 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_04_22.tif
# anwr image 6 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_05_08.tif
# anwr image 7 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_05_24.tif
# anwr image 8 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_06_09.tif
# anwr image 9 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_06_25.tif
# anwr image 10 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_07_11.tif
# anwr image 11 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_07_27.tif
# anwr image 12 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_08_12.tif
# anwr image 13 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_08_28.tif
# anwr image 14 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_09_13.tif
# anwr image 15 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_09_29.tif
# anwr image 16 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_10_15.tif
# anwr image 17 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_10_31.tif
# anwr image 18 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_11_16.tif
# anwr image 19 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_12_02.tif
# anwr image 20 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2000_12_18.tif
# anwr image 21 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_01_01.tif
# anwr image 22 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_01_17.tif
# anwr image 23 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_02_02.tif
# anwr image 24 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_02_18.tif
# anwr image 25 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_03_06.tif
# anwr image 26 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_03_22.tif
# anwr image 27 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_04_07.tif
# anwr image 28 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_04_23.tif
# anwr image 29 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_05_09.tif
# anwr image 30 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_05_25.tif
# anwr image 31 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_06_10.tif
# anwr image 32 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_06_26.tif
# anwr image 33 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_07_12.tif
# anwr image 34 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_07_28.tif
# anwr image 35 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_08_13.tif
# anwr image 36 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_08_29.tif
# anwr image 37 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_09_14.tif
# anwr image 38 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_09_30.tif
# anwr image 39 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_10_16.tif
# anwr image 40 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_11_01.tif
# anwr image 41 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001_11_17.tif
# anwr image 42 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2001
out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_07_28.tif
# anwr image 127 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_08_13.tif
# anwr image 128 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_08_29.tif
# anwr image 129 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_09_14.tif
# anwr image 130 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_09_30.tif
# anwr image 131 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_10_16.tif
# anwr image 132 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_11_01.tif
# anwr image 133 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_11_17.tif
# anwr image 134 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_12_03.tif
# anwr image 135 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2005_12_19.tif
# anwr image 136 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_01_01.tif
# anwr image 137 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_01_17.tif
# anwr image 138 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_02_02.tif
# anwr image 139 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_02_18.tif
# anwr image 140 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_03_06.tif
# anwr image 141 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_03_22.tif
# anwr image 142 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_04_07.tif
# anwr image 143 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_04_23.tif
# anwr image 144 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_05_09.tif
# anwr image 145 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_05_25.tif
# anwr image 146 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_06_10.tif
# anwr image 147 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_06_26.tif
# anwr image 148 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_07_12.tif
# anwr image 149 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_07_28.tif
# anwr image 150 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_08_13.tif
# anwr image 151 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_08_29.tif
# anwr image 152 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_09_14.tif
# anwr image 153 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_09_30.tif
# anwr image 154 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_10_16.tif
# anwr image 155 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_11_01.tif
# anwr image 156 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_11_17.tif
# anwr image 157 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_12_03.tif
# anwr image 158 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2006_12_19.tif
# anwr image 159 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_01_01.tif
# anwr image 160 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_01_17.tif
# anwr image 161 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_02_02.tif
# anwr image 162 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_02_18.tif
# anwr image 163 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_03_06.tif
# anwr image 164 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_03_22.tif
# anwr image 165 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_04_07.tif
# anwr image 166 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_04_23.tif
# anwr image 167 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_05_09.tif
# anwr image 168 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_05_25.tif
# anwr image 169 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_06_10.tif
# anwr image 170 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_06_26.tif
# anwr image 171 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_07_12.tif
# anwr image 172 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_07_28.tif
# anwr image 173 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_08_13.tif
# anwr image 174 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_08_29.tif
# anwr image 175 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_09_14.tif
# anwr image 176 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_09_30.tif
# anwr image 177 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_10_16.tif
# anwr image 178 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_11_01.tif
# anwr image 179 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_11_17.tif
# anwr image 180 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_12_03.tif
# anwr image 181 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2007_12_19.tif
# anwr image 182 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2008_01_01.tif
# anwr image 183 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2008_01_17.tif
# anwr image 184 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2008_02_02.tif
# anwr image 185 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2008_02_18.tif
# anwr image 186 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2008_03_05.tif
# anwr image 187 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2008_03_21.tif
# anwr image 188 out of 494
# Filename: /datadrive/MODIS_NDVI_Alaska/modis/tiffs/anwr/2008_04_06.tif
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-d81e54253cc5> in <module>
#       5     for i, f in enumerate(files[key]):
#       6         print(f"{key} image {i+1} out of {len(files[key])}")
# ----> 7         save_tiff_numpy(OUT_DIR, f, value)
#
# /datadrive/MODIS_NDVI_Alaska/utils.py in save_tiff_numpy(out_dir, tiff_fname, mask, vflip)
#     182 def save_tiff_numpy(out_dir, tiff_fname, mask, vflip=False):
#     183     print(f"Filename: {tiff_fname}")
# --> 184     x = np.squeeze(rasterio.open(tiff_fname).read())
#     185     mask = np.squeeze(mask)
#     186     x[mask == 0] = -2000
#
# KeyboardInterrupt:
